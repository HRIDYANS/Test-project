# %% [markdown]
# <a href="https://colab.research.google.com/github/HRIDYANS/Test-project/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("namesh")
# Out:
# namesh

# %%
num=1
num1=2
num3=num+num1
print(num3)
# Out:
# 3

# %%
def add_numbers(num1,num2):
  result = num1+num2
  print(result)

# %%
add_numbers(78,99)
# Out:
# 177

# %%
l1=[22,34,56,77]
print(l1)
# Out:
# [22, 34, 56, 77]

# %%
l1=['nehal',89000,78]
