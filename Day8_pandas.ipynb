# %% [markdown]
# <a href="https://colab.research.google.com/github/HRIDYANS/Test-project/blob/main/Day8_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import library

# %%
import pandas as pd
# we are importing library named pandas
#pandas is used to read, manipulate data

# %% [markdown]
# Reading the file

# %%
#getting the file path
filepath="/content/auto-mpg.csv"
#reading the file using the path to the file
#and storing it as 'df_auto'
df_auto = pd.read_csv(filepath)

print(df_auto)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df_auto.shape
# Out:
# (398, 9)

# %%
df_auto.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df_auto.mpg
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
df_auto['acceleration']
# Out:
# 0      12.0
# 1      11.5
# 2      11.0
# 3      12.0
# 4      10.5
#        ...
# 393    15.6
# 394    24.6
# 395    11.6
# 396    18.6
# 397    19.4
# Name: acceleration, Length: 398, dtype: float64

# %%
df_auto[['acceleration','displacement']]
# Out:
#      acceleration  displacement
# 0            12.0         307.0
# 1            11.5         350.0
# 2            11.0         318.0
# 3            12.0         304.0
# 4            10.5         302.0
# ..            ...           ...
# 393          15.6         140.0
# 394          24.6          97.0
# 395          11.6         135.0
# 396          18.6         120.0
# 397          19.4         119.0
#
# [398 rows x 2 columns]

# %%
df_auto.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
df_auto.isnull()
# Out:
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    False      False         False       False   False         False
# 1    False      False         False       False   False         False
# 2    False      False         False       False   False         False
# 3    False      False         False       False   False         False
# 4    False      False         False       False   False         False
# ..     ...        ...           ...         ...     ...           ...
# 393  False      False         False       False   False         False
# 394  False      False         False       False   False         False
# 395  False      False         False       False   False         False
# 396  False      False         False       False   False         False
# 397  False      False         False       False   False         False
#
#      model year  origin  car name
# 0         False   False     False
# 1         False   False     False
# ...

# %%
df_auto.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df_auto.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df_auto_mpg_edited = pd.read_csv("/content/auto-mpg-edited.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2736122354.py in <cell line: 0>()
# ----> 1 df_auto_mpg_edited = pd.read_csv("/content/auto-mpg-edited.csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df_auto['model year'].unique()
# Out:
# array([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82])

# %%
df_auto['weight'].unique()
# Out:
# array([3504, 3693, 3436, 3433, 3449, 4341, 4354, 4312, 4425, 3850, 3563,
#        3609, 3761, 3086, 2372, 2833, 2774, 2587, 2130, 1835, 2672, 2430,
#        2375, 2234, 2648, 4615, 4376, 4382, 4732, 2264, 2228, 2046, 2634,
#        3439, 3329, 3302, 3288, 4209, 4464, 4154, 4096, 4955, 4746, 5140,
#        2962, 2408, 3282, 3139, 2220, 2123, 2074, 2065, 1773, 1613, 1834,
#        1955, 2278, 2126, 2254, 2226, 4274, 4385, 4135, 4129, 3672, 4633,
#        4502, 4456, 4422, 2330, 3892, 4098, 4294, 4077, 2933, 2511, 2979,
#        2189, 2395, 2288, 2506, 2164, 2100, 4100, 3988, 4042, 3777, 4952,
#        4363, 4237, 4735, 4951, 3821, 3121, 3278, 2945, 3021, 2904, 1950,
#        4997, 4906, 4654, 4499, 2789, 2279, 2401, 2379, 2124, 2310, 2472,
#        2265, 4082, 4278, 1867, 2158, 2582, 2868, 3399, 2660, 2807, 3664,
#        3102, 2875, 2901, 3336, 2451, 1836, 2542, 3781, 3632, 3613, 4141,
#        4699, 4457, 4638, 4257, 2219, 1963, 2300, 1649, 2003, 2125, 2108,
# ...

# %%
df_auto['weight'].nunique()
# Out:
# 351

# %%
df_auto['model year'].nunique()
# Out:
# 13

# %%
df_auto['model year'].value_counts()
# Out:
# model year
# 73    40
# 78    36
# 76    34
# 82    31
# 75    30
# 80    29
# 79    29
# 81    29
# 70    29
# 71    28
# 72    28
# 77    28
# 74    27
# Name: count, dtype: int64

# %%
df_auto['origin'].value_counts()
# Out:
# origin
# 1    249
# 3     79
# 2     70
# Name: count, dtype: int64

# %%
df_auto.groupby('origin')['mpg'].mean()
# Out:
# origin
# 1    20.083534
# 2    27.891429
# 3    30.450633
# Name: mpg, dtype: float64

# %%
df_auto.isnull()
# Out:
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    False      False         False       False   False         False
# 1    False      False         False       False   False         False
# 2    False      False         False       False   False         False
# 3    False      False         False       False   False         False
# 4    False      False         False       False   False         False
# ..     ...        ...           ...         ...     ...           ...
# 393  False      False         False       False   False         False
# 394  False      False         False       False   False         False
# 395  False      False         False       False   False         False
# 396  False      False         False       False   False         False
# 397  False      False         False       False   False         False
#
#      model year  origin  car name
# 0         False   False     False
# 1         False   False     False
# ...

# %%
df_auto.groupby('origin')[['mpg','weight']].mean()
# Out:
#               mpg       weight
# origin
# 1       20.083534  3361.931727
# 2       27.891429  2423.300000
# 3       30.450633  2221.227848

# %%
df_auto.loc[:,'mpg']
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
df_auto.loc[0:10,['mpg','weight']]
# Out:
#      mpg  weight
# 0   18.0    3504
# 1   15.0    3693
# 2   18.0    3436
# 3   16.0    3433
# 4   17.0    3449
# 5   15.0    4341
# 6   14.0    4354
# 7   14.0    4312
# 8   14.0    4425
# 9   15.0    3850
# 10  15.0    3563

# %%
df_auto['horsepower'].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
df_auto['horsepower']
pd.to_numeric(df_auto['horsepower'],errors='coerce')
# Out:
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
#        ...
# 393     86.0
# 394     52.0
# 395     84.0
# 396     79.0
# 397     82.0
# Name: horsepower, Length: 398, dtype: float64

# %%
pd.to_numeric(df_auto['horsepower'],errors='coerce')
df_auto['horsepower']

1
2
3
"?"
# Out:
# '?'

# %%
#check for non number and foreces the to be
#converted to number values
#errors=coerce
pd.to_numeric(df_auto['horsepower'],errors='coerce')
df_auto['horsepower']
# Out:
# 0      130
# 1      165
# 2      150
# 3      150
# 4      140
#       ...
# 393     86
# 394     52
# 395     84
# 396     79
# 397     82
# Name: horsepower, Length: 398, dtype: object

# %%
pd.to_numeric(df_auto['horsepower'],errors='coerce')
df_auto['horsepower'].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
df_auto.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df_auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
mean_hp = df_auto.horsepower.mean()
mean_hp
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3476972641.py in <cell line: 0>()
# ----> 1 mean_hp = df_auto.horsepower.mean()
#       2 mean_hp
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6547         **kwargs,
#    6548     ):
# -> 6549         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6550
#    6551     @doc(make_doc("median", ndim=1))
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# ...

# %%
df_auto['horsepower'].fillna(mean_hp)
df_auto['horsepower'].fillna(mean_hp, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4205543510.py in <cell line: 0>()
# ----> 1 df_auto['horsepower'].fillna(mean_hp)
#       2 df_auto['horsepower'].fillna(mean_hp, inplace=True)
#
# NameError: name 'mean_hp' is not defined

# %%
df_auto.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df_auto['horsepower']=df_auto['horsepower'].fillna(mean_hp)
df_auto['horsepower'].fillna(mean_hp), inplace=True
# Out:
#   File "/tmp/ipython-input-1325044662.py", line 2
#     df_auto['horsepower'].fillna(mean_hp), inplace=True
#                                            ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
df_auto['proper model year'] =df_auto['model year']+1900

# %%
df_auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name  proper model year
# 0            70       1  chevrolet chevelle malibu               1970
# ...

# %%
#remove the column 'model year'
df_auto_dummy = df_auto.drop('model year',axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3024771872.py in <cell line: 0>()
#       1 #remove the column 'model year'
# ----> 2 df_auto_dummy = df_auto.drop('model year',axis=1, inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df_auto_dummy.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3441317777.py in <cell line: 0>()
# ----> 1 df_auto_dummy.head(2)
#
# NameError: name 'df_auto_dummy' is not defined
